# %% [markdown]
# ### - Business understanding
#
# the aim of this project is analysis the data , the data is about the scholareship for students , the data comes form ministry of education for saudi arabia , the project try to answer three Quesetions ,
#   - the first Q is : Q1/ How many student have scholarship ?
#   - the second Q is : Q2/ How many student according the country ?
#   - the third Q is : Q3/ which degrees have alot of students ?
# - the analysis tools is python 3 .
# - the other purpose to from this analysis try to creat plan for budget .
#
# the link of the project :
# - https://github.com/nourahamads/Scholarship-Data

# %% [markdown]
# ### - Data understanding
#   Data is basic and stored in thr CSV file . there is 8484 rows total , and 9 columns  ,
#   the data source from Ministry of Education in the SAudi Arabia

# %% [markdown]
# ### - Data preparation
#  there is not have alote of missing data . so there was two rows have the missing value , so I drop it it is not alot so  not will be affecting the results

# %% [markdown]
# ### - Data Modeling
# in this part try to answer  tha Qustions

# %% [markdown]
#  ##### the fist Question is How many  students according the cuntries
#  this Gragh visualize the data and try to discover the number of the student according the country

# %% [markdown]
# ![untitled12.png](attachment:untitled12.png)

# %% [markdown]
# The graph below is visualize the number of the studnet according the dagree

# %% [markdown]
# ![untitled11.png](attachment:untitled11.png)

# %% [markdown]
# ### Evalaution

# %% [markdown]
# - Evalaution
#
# we have three Qustions we need to answer it
# - Q1/ How many student have scholarship ?
# the student is about 8484 , in the scholarship .
# this number with rows have nulls value but the number of the student without nulls value 8482 studends in the scholarship .

# %% [markdown]
# - Q2/ How many student according the country ?
# The most country have students is is Britain is about 2828 studens , and then Australia is about 2144 students , then US 1388 students
# Now discover this table about the countries :
#
# - أسبانيا:      	3
# - ألمانيا:  	574
# - استراليا:	2144
# - الأردن  :	122
# - الامارات العربية المتحده  :	21
# - التشيك:  	2
# - الجمهوريه العربية السورية  :	1
# - الجمهوريه اللبنانيه :	3
# - السويد : 	90
# - الصين :  	9
# - المملكة العربية السعودية:	251
# - النمسا:  	5
# - الهند :  	1
# - الولايات المتحدة الامريكية :	1388
# - اليابان: 	9
# - اليونان: 	1
# - ايرلندا :	20
# - ايطاليا: 	4
# - باكستان: 	1
# - بريطانيا	2828:
# - بلجيكا:  	33
# - تايوان:  	1
# - تركيا  : 	1
# - جمهورية مصر العربية :	26
# - جنوب أفريقيا: 	5
# - سنغافورا:	5
# - سويسرا : 	29
# - فرنسا:	190
# - كندا:	531
# - كوريا الجنوبية : 	41
# - ماليزيا: 	39
# - مملكة البحرين:	25
# - نيوزلندا:	55
# - هولندا:	24

# %% [markdown]
# - Q3/ which degrees have alot of students ?
#   - as we will see the most degrees the students have scholarship is :
#     master is about 3860 students ,
#      and Bachelor is about 2026,
#      and then docterat is about 1007 students .

# %% [markdown]
# #####  finally the purpose of this project try to discover the data and creat a plan for budget , the next stepe is  get more datasete and try to forcast it the next year .
